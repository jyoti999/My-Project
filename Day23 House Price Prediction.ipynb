# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
df1= pd.read_csv("C:\\Noble\\Training\\Top Mentor\\Training\\Data Set\\House Price.csv")
print (df1)
# Out:
#         Id  LotFrontage  LotArea Alley  MasVnrArea  1stFlrSF  2ndFlrSF  \
# 0        1         65.0     8450   NaN       196.0       856       854
# 1        2         80.0     9600   NaN         0.0      1262         0
# 2        3         68.0    11250   NaN       162.0       920       866
# 3        4         60.0     9550   NaN         0.0       961       756
# 4        5         84.0    14260   NaN       350.0      1145      1053
# ...    ...          ...      ...   ...         ...       ...       ...
# 1455  1456         62.0     7917   NaN         0.0       953       694
# 1456  1457         85.0    13175   NaN       119.0      2073         0
# 1457  1458         66.0     9042   NaN         0.0      1188      1152
# 1458  1459         68.0     9717   NaN         0.0      1078         0
# 1459  1460         75.0     9937   NaN         0.0      1256         0
#
#       GrLivArea GarageType  GarageArea  SalePrice
# 0          1710     Attchd         548     208500
# ...

# %%
pd.set_option('display.width', 2000)

# %%
df1= pd.read_csv("C:\\Noble\\Training\\Top Mentor\\Training\\Data Set\\House Price.csv")
print (df1)
# Out:
#         Id  LotFrontage  LotArea Alley  MasVnrArea  1stFlrSF  2ndFlrSF  GrLivArea GarageType  GarageArea  SalePrice
# 0        1         65.0     8450   NaN       196.0       856       854       1710     Attchd         548     208500
# 1        2         80.0     9600   NaN         0.0      1262         0       1262     Attchd         460     181500
# 2        3         68.0    11250   NaN       162.0       920       866       1786     Attchd         608     223500
# 3        4         60.0     9550   NaN         0.0       961       756       1717     Detchd         642     140000
# 4        5         84.0    14260   NaN       350.0      1145      1053       2198     Attchd         836     250000
# ...    ...          ...      ...   ...         ...       ...       ...        ...        ...         ...        ...
# 1455  1456         62.0     7917   NaN         0.0       953       694       1647     Attchd         460     175000
# ...

# %%
DV = input ('Enter the dependent variable')
position_DV = df1.columns.get_loc(DV)
print (position_DV)
# Out:
# Enter the dependent variableSalePrice
# 10

# %%
print (len(df1))
# Out:
# 1460

# %%
print (df1.count())
# Out:
# Id             1460
# LotFrontage    1201
# LotArea        1460
# Alley            91
# MasVnrArea     1452
# 1stFlrSF       1460
# 2ndFlrSF       1460
# GrLivArea      1460
# GarageType     1379
# GarageArea     1460
# SalePrice      1460
# dtype: int64

# %%
print (df1.size)
# Out:
# 16060

# %%
1460*11
# Out:
# 16060

# %%
print (df1.isnull().any)
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.any of          Id  LotFrontage  LotArea  Alley  MasVnrArea  1stFlrSF  2ndFlrSF  GrLivArea  GarageType  GarageArea  SalePrice
# 0     False        False    False   True       False     False     False      False       False       False      False
# 1     False        False    False   True       False     False     False      False       False       False      False
# 2     False        False    False   True       False     False     False      False       False       False      False
# 3     False        False    False   True       False     False     False      False       False       False      False
# 4     False        False    False   True       False     False     False      False       False       False      False
# ...     ...          ...      ...    ...         ...       ...       ...        ...         ...         ...        ...
# ...

# %%
print (df1.isnull().sum())
# Out:
# Id                0
# LotFrontage     259
# LotArea           0
# Alley          1369
# MasVnrArea        8
# 1stFlrSF          0
# 2ndFlrSF          0
# GrLivArea         0
# GarageType       81
# GarageArea        0
# SalePrice         0
# dtype: int64

# %%
FileNameDesc = pd.DataFrame(columns=['ColumnName', 'MissingCount','MissingPercentage','UniqueValues'])
FileNameDesc
# Out:
# Empty DataFrame
# Columns: [ColumnName, MissingCount, MissingPercentage, UniqueValues]
# Index: []

# %%
df1.columns
# Out:
# Index(['Id', 'LotFrontage', 'LotArea', 'Alley', 'MasVnrArea', '1stFlrSF', '2ndFlrSF', 'GrLivArea', 'GarageType', 'GarageArea', 'SalePrice'], dtype='object')

# %%
for col in list(df1.columns.values):
     print (col)
# Out:
# Id
# LotFrontage
# LotArea
# Alley
# MasVnrArea
# 1stFlrSF
# 2ndFlrSF
# GrLivArea
# GarageType
# GarageArea
# SalePrice

# %%
df1['LotFrontage'].isnull().sum()
# Out:
# 259

# %%
259/1460
# Out:
# 0.1773972602739726

# %%
FileNameDesc = pd.DataFrame(columns=['ColumnName', 'MissingCount','MissingPercentage','UniqueValues'])

for col in list(df1.columns.values):
    sum_missing = df1[col].isnull().sum()
    percent_missing = (sum_missing/len(df1)) *100
    uniq_count =(df1.groupby ([col])[col].count()).count()
    FileNameDesc = FileNameDesc.append ({'ColumnName': col,'MissingCount':sum_missing,'MissingPercentage': percent_missing,
                                        'UniqueValues': uniq_count} ,ignore_index=True  )

# %%
print (FileNameDesc)
# Out:
#      ColumnName MissingCount  MissingPercentage UniqueValues
# 0            Id            0           0.000000         1460
# 1   LotFrontage          259          17.739726          110
# 2       LotArea            0           0.000000         1073
# 3         Alley         1369          93.767123            2
# 4    MasVnrArea            8           0.547945          327
# 5      1stFlrSF            0           0.000000          753
# 6      2ndFlrSF            0           0.000000          417
# 7     GrLivArea            0           0.000000          861
# 8    GarageType           81           5.547945            6
# 9    GarageArea            0           0.000000          441
# 10    SalePrice            0           0.000000          663

# %%
df1.dtypes
# Out:
# Id               int64
# LotFrontage    float64
# LotArea          int64
# Alley           object
# MasVnrArea     float64
# 1stFlrSF         int64
# 2ndFlrSF         int64
# GrLivArea        int64
# GarageType      object
# GarageArea       int64
# SalePrice        int64
# dtype: object

# %%
FileColType = (df1.dtypes).reset_index()
print ( FileColType)
# Out:
#           index        0
# 0            Id    int64
# 1   LotFrontage  float64
# 2       LotArea    int64
# 3         Alley   object
# 4    MasVnrArea  float64
# 5      1stFlrSF    int64
# 6      2ndFlrSF    int64
# 7     GrLivArea    int64
# 8    GarageType   object
# 9    GarageArea    int64
# 10    SalePrice    int64

# %%
FileNameDesc = FileNameDesc.merge(FileColType, left_on ='ColumnName',right_on ='index',how ='inner')
FileNameDesc
# Out:
#      ColumnName MissingCount  MissingPercentage UniqueValues        index        0
# 0            Id            0           0.000000         1460           Id    int64
# 1   LotFrontage          259          17.739726          110  LotFrontage  float64
# 2       LotArea            0           0.000000         1073      LotArea    int64
# 3         Alley         1369          93.767123            2        Alley   object
# 4    MasVnrArea            8           0.547945          327   MasVnrArea  float64
# 5      1stFlrSF            0           0.000000          753     1stFlrSF    int64
# 6      2ndFlrSF            0           0.000000          417     2ndFlrSF    int64
# 7     GrLivArea            0           0.000000          861    GrLivArea    int64
# 8    GarageType           81           5.547945            6   GarageType   object
# 9    GarageArea            0           0.000000          441   GarageArea    int64
# ...

# %%
del FileNameDesc['index']
display (FileNameDesc)
# Out:
#      ColumnName MissingCount  MissingPercentage UniqueValues        0
# 0            Id            0           0.000000         1460    int64
# 1   LotFrontage          259          17.739726          110  float64
# 2       LotArea            0           0.000000         1073    int64
# 3         Alley         1369          93.767123            2   object
# 4    MasVnrArea            8           0.547945          327  float64
# 5      1stFlrSF            0           0.000000          753    int64
# 6      2ndFlrSF            0           0.000000          417    int64
# 7     GrLivArea            0           0.000000          861    int64
# 8    GarageType           81           5.547945            6   object
# 9    GarageArea            0           0.000000          441    int64
# 10    SalePrice            0           0.000000          663    int64

# %%
FileNameDesc = FileNameDesc.rename(index=str, columns = {0:"DataType"})
print (FileNameDesc)
# Out:
#      ColumnName MissingCount  MissingPercentage UniqueValues DataType
# 0            Id            0           0.000000         1460    int64
# 1   LotFrontage          259          17.739726          110  float64
# 2       LotArea            0           0.000000         1073    int64
# 3         Alley         1369          93.767123            2   object
# 4    MasVnrArea            8           0.547945          327  float64
# 5      1stFlrSF            0           0.000000          753    int64
# 6      2ndFlrSF            0           0.000000          417    int64
# 7     GrLivArea            0           0.000000          861    int64
# 8    GarageType           81           5.547945            6   object
# 9    GarageArea            0           0.000000          441    int64
# 10    SalePrice            0           0.000000          663    int64

# %%
df1.drop(['Alley'], axis = 1, inplace = True)
print (df1)
# Out:
#         Id  LotFrontage  LotArea  MasVnrArea  1stFlrSF  2ndFlrSF  GrLivArea GarageType  GarageArea  SalePrice
# 0        1         65.0     8450       196.0       856       854       1710     Attchd         548     208500
# 1        2         80.0     9600         0.0      1262         0       1262     Attchd         460     181500
# 2        3         68.0    11250       162.0       920       866       1786     Attchd         608     223500
# 3        4         60.0     9550         0.0       961       756       1717     Detchd         642     140000
# 4        5         84.0    14260       350.0      1145      1053       2198     Attchd         836     250000
# ...    ...          ...      ...         ...       ...       ...        ...        ...         ...        ...
# 1455  1456         62.0     7917         0.0       953       694       1647     Attchd         460     175000
# ...

# %%
def remove_outlier(df_in, col_name):
    q1 = df_in[col_name].quantile(0.25)
    q3 = df_in[col_name].quantile(0.75)
    iqr = q3-q1
    fence_low = q1 - 1.5*iqr
    fence_high = q3 + 1.5*iqr
    df_out = df_in.loc[(df_in[col_name]> fence_low) & (df_in[col_name] < fence_high)]
    return df_out

# %%
df1.describe()
# Out:
#                 Id  LotFrontage        LotArea   MasVnrArea     1stFlrSF     2ndFlrSF    GrLivArea   GarageArea      SalePrice
# count  1460.000000  1201.000000    1460.000000  1452.000000  1460.000000  1460.000000  1460.000000  1460.000000    1460.000000
# mean    730.500000    70.049958   10516.828082   103.685262  1162.626712   346.992466  1515.463699   472.980137  180921.195890
# std     421.610009    24.284752    9981.264932   181.066207   386.587738   436.528436   525.480383   213.804841   79442.502883
# min       1.000000    21.000000    1300.000000     0.000000   334.000000     0.000000   334.000000     0.000000   34900.000000
# 25%     365.750000    59.000000    7553.500000     0.000000   882.000000     0.000000  1129.500000   334.500000  129975.000000
# 50%     730.500000    69.000000    9478.500000     0.000000  1087.000000     0.000000  1464.000000   480.000000  163000.000000
# ...

# %%
df1.dtypes
# Out:
# Id               int64
# LotFrontage    float64
# LotArea          int64
# MasVnrArea     float64
# 1stFlrSF         int64
# 2ndFlrSF         int64
# GrLivArea        int64
# GarageType      object
# GarageArea       int64
# SalePrice        int64
# dtype: object

# %%
df_col=FileNameDesc[(FileNameDesc.DataType=='int64') | (FileNameDesc.DataType =='float64')]
print (df_col)
# Out:
#      ColumnName MissingCount  MissingPercentage UniqueValues DataType
# 0            Id            0           0.000000         1460    int64
# 1   LotFrontage          259          17.739726          110  float64
# 2       LotArea            0           0.000000         1073    int64
# 4    MasVnrArea            8           0.547945          327  float64
# 5      1stFlrSF            0           0.000000          753    int64
# 6      2ndFlrSF            0           0.000000          417    int64
# 7     GrLivArea            0           0.000000          861    int64
# 9    GarageArea            0           0.000000          441    int64
# 10    SalePrice            0           0.000000          663    int64

# %%
for col_na in df_col['ColumnName']:
    if col_na != DV:
        df1= remove_outlier(df1, col_na)

# %%
print (df1.isnull().sum())
# Out:
# Id              0
# LotFrontage     0
# LotArea         0
# MasVnrArea      0
# 1stFlrSF        0
# 2ndFlrSF        0
# GrLivArea       0
# GarageType     64
# GarageArea      0
# SalePrice       0
# dtype: int64

# %%
df1.shape
# Out:
# (968, 10)

# %%
df1.describe()
# Out:
#                 Id  LotFrontage       LotArea  MasVnrArea     1stFlrSF     2ndFlrSF    GrLivArea  GarageArea      SalePrice
# count   968.000000   968.000000    968.000000  968.000000   968.000000   968.000000   968.000000  968.000000     968.000000
# mean    727.568182    67.440083   8999.138430   61.491736  1111.181818   299.678719  1416.559917  446.429752  166773.433884
# std     421.028118    15.882275   2621.022408  102.259276   313.421737   396.099302   410.784283  204.551592   63129.765172
# min       1.000000    30.000000   2448.000000    0.000000   334.000000     0.000000   334.000000    0.000000   34900.000000
# 25%     374.750000    60.000000   7378.500000    0.000000   873.500000     0.000000  1106.750000  300.000000  125000.000000
# 50%     728.500000    67.000000   9000.000000    0.000000  1053.500000     0.000000  1379.500000  462.000000  152000.000000
# ...

# %%
df1.groupby('GarageType').agg({'GarageType': np.size})
# Out:
#             GarageType
# GarageType
# 2Types               4
# Attchd             542
# Basment             10
# BuiltIn             44
# CarPort              8
# Detchd             296

# %%
df1["GarageType"]=df1["GarageType"].fillna('Attchd')

# %%
df1.groupby('GarageType').agg({'GarageType': np.size})
# Out:
#             GarageType
# GarageType
# 2Types               4
# Attchd             606
# Basment             10
# BuiltIn             44
# CarPort              8
# Detchd             296

# %%
df1["GarageType"] = df1["GarageType"].astype('category')

# %%
df1["GarageType"] = df1["GarageType"].cat.codes

# %%
df1.groupby('GarageType').agg({'GarageType': np.size})
# Out:
#             GarageType
# GarageType
# 0                    4
# 1                  606
# 2                   10
# 3                   44
# 4                    8
# 5                  296

# %%
FileColType = (df1.dtypes)
print ( FileColType)
# Out:
# Id               int64
# LotFrontage    float64
# LotArea          int64
# MasVnrArea     float64
# 1stFlrSF         int64
# 2ndFlrSF         int64
# GrLivArea        int64
# GarageType        int8
# GarageArea       int64
# SalePrice        int64
# dtype: object

# %%
df1.shape
# Out:
# (968, 10)

# %%
df1 = pd.get_dummies(df1, columns=['GarageType'], drop_first=True)
# Out:
#         Id  LotFrontage  LotArea  MasVnrArea  1stFlrSF  2ndFlrSF  GrLivArea  GarageArea  SalePrice  GarageType_1  GarageType_2  GarageType_3  GarageType_4  GarageType_5
# 0        1         65.0     8450       196.0       856       854       1710         548     208500             1             0             0             0             0
# 1        2         80.0     9600         0.0      1262         0       1262         460     181500             1             0             0             0             0
# 2        3         68.0    11250       162.0       920       866       1786         608     223500             1             0             0             0             0
# 3        4         60.0     9550         0.0       961       756       1717         642     140000             0             0             0             0             1
# ...

# %%
display (df1)
# Out:
#         Id  LotFrontage  LotArea  MasVnrArea  1stFlrSF  2ndFlrSF  GrLivArea  GarageArea  SalePrice  GarageType_1  GarageType_2  GarageType_3  GarageType_4  GarageType_5
# 0        1         65.0     8450       196.0       856       854       1710         548     208500             1             0             0             0             0
# 1        2         80.0     9600         0.0      1262         0       1262         460     181500             1             0             0             0             0
# 2        3         68.0    11250       162.0       920       866       1786         608     223500             1             0             0             0             0
# 3        4         60.0     9550         0.0       961       756       1717         642     140000             0             0             0             0             1
# ...

# %%
df1.to_csv('C:\\Noble\\Training\\Top Mentor\\Training\\LMS\\Feb 2022\\Batch60 Day23\\Sample1.csv')
os.getcwd()
# Out:
# 'C:\\Users\\noble'

# %%
df1
# Out:
#         Id  LotFrontage  LotArea  MasVnrArea  1stFlrSF  2ndFlrSF  GrLivArea  GarageArea  SalePrice  GarageType_1  GarageType_2  GarageType_3  GarageType_4  GarageType_5
# 0        1         65.0     8450       196.0       856       854       1710         548     208500             1             0             0             0             0
# 1        2         80.0     9600         0.0      1262         0       1262         460     181500             1             0             0             0             0
# 2        3         68.0    11250       162.0       920       866       1786         608     223500             1             0             0             0             0
# 3        4         60.0     9550         0.0       961       756       1717         642     140000             0             0             0             0             1
# ...

# %%
df=df1['SalePrice']
df1.drop(['SalePrice'], axis = 1, inplace = True)
df1=pd.concat([df1,df],axis=1)
print (df1)
# Out:
#         Id  LotFrontage  LotArea  MasVnrArea  1stFlrSF  2ndFlrSF  GrLivArea  GarageArea  GarageType_1  GarageType_2  GarageType_3  GarageType_4  GarageType_5  SalePrice
# 0        1         65.0     8450       196.0       856       854       1710         548             1             0             0             0             0     208500
# 1        2         80.0     9600         0.0      1262         0       1262         460             1             0             0             0             0     181500
# 2        3         68.0    11250       162.0       920       866       1786         608             1             0             0             0             0     223500
# 3        4         60.0     9550         0.0       961       756       1717         642             0             0             0             0             1     140000
# ...

# %%
len(df1)
df1.head()
df1.isnull().any()
df1.isnull().sum()
# Out:
# Id              0
# LotFrontage     0
# LotArea         0
# MasVnrArea      0
# 1stFlrSF        0
# 2ndFlrSF        0
# GrLivArea       0
# GarageArea      0
# GarageType_1    0
# GarageType_2    0
# GarageType_3    0
# GarageType_4    0
# GarageType_5    0
# SalePrice       0
# dtype: int64

# %%
display (df1)
# Out:
#         Id  LotFrontage  LotArea  MasVnrArea  1stFlrSF  2ndFlrSF  GrLivArea  GarageArea  GarageType_1  GarageType_2  GarageType_3  GarageType_4  GarageType_5  SalePrice
# 0        1         65.0     8450       196.0       856       854       1710         548             1             0             0             0             0     208500
# 1        2         80.0     9600         0.0      1262         0       1262         460             1             0             0             0             0     181500
# 2        3         68.0    11250       162.0       920       866       1786         608             1             0             0             0             0     223500
# 3        4         60.0     9550         0.0       961       756       1717         642             0             0             0             0             1     140000
# ...

# %%
sns.pairplot(df1)

# %%
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 20,10
df1.corr()
sns.heatmap(df1.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
x = df1.iloc[:,1:13]
x
# Out:
#       LotFrontage  LotArea  MasVnrArea  1stFlrSF  2ndFlrSF  GrLivArea  GarageArea  GarageType_1  GarageType_2  GarageType_3  GarageType_4  GarageType_5
# 0            65.0     8450       196.0       856       854       1710         548             1             0             0             0             0
# 1            80.0     9600         0.0      1262         0       1262         460             1             0             0             0             0
# 2            68.0    11250       162.0       920       866       1786         608             1             0             0             0             0
# 3            60.0     9550         0.0       961       756       1717         642             0             0             0             0             1
# 4            84.0    14260       350.0      1145      1053       2198         836             1             0             0             0             0
# ...

# %%
y = df1.iloc[:,13:]
y
# Out:
#       SalePrice
# 0        208500
# 1        181500
# 2        223500
# 3        140000
# 4        250000
# ...         ...
# 1454     185000
# 1455     175000
# 1457     266500
# 1458     142125
# 1459     147500
#
# [968 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 100)

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm = lm.fit(x_train,y_train)

# %%
lm.coef_
# Out:
# array([[-1.81351101e+02,  1.56120674e+00,  5.93409547e+01,
#          9.92195033e+01,  6.90486066e+01, -1.58013081e+01,
#          1.15552385e+02,  9.53670713e+04,  5.63375974e+04,
#          1.09086377e+05,  4.25797036e+04,  6.77729143e+04]])

# %%
coefficients = pd.concat([pd.DataFrame(x_train.columns),pd.DataFrame(np.transpose(lm.coef_))], axis = 1)
print (coefficients)
# Out:
#                0              0
# 0    LotFrontage    -181.351101
# 1        LotArea       1.561207
# 2     MasVnrArea      59.340955
# 3       1stFlrSF      99.219503
# 4       2ndFlrSF      69.048607
# 5      GrLivArea     -15.801308
# 6     GarageArea     115.552385
# 7   GarageType_1   95367.071262
# 8   GarageType_2   56337.597440
# 9   GarageType_3  109086.377285
# 10  GarageType_4   42579.703601
# 11  GarageType_5   67772.914294

# %%
lm.intercept_
# Out:
# array([-85131.01187576])

# %%
y_pred = lm.predict(x_test)

# %%
y_error = y_test - y_pred
y_error
# Out:
#          SalePrice
# 562    4392.835388
# 1433 -18318.060293
# 869    8011.334987
# 573   -1450.094361
# 1144 -12606.348762
# ...            ...
# 279  -37444.285658
# 155  -10959.370136
# 146   28262.068321
# 735   16709.754668
# 1052 -59743.950804
#
# [194 rows x 1 columns]

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.6455125278161816

# %%
from sklearn.model_selection import cross_val_score
cvm= cross_val_score(lm, x, y, cv=5)
pd.DataFrame(cvm)
# Out:
#           0
# 0  0.746842
# 1  0.750564
# 2  0.572558
# 3  0.688567
# 4  0.629581

# %%
print ('Mean', cvm.mean())
print ('STD',cvm.std())
# Out:
# Mean 0.6776223998131453
# STD 0.06867036797730634

# %%
import statsmodels.api as sma
x_train = sma.add_constant(x_train) 
## let's add an intercept (beta_0) to our model
x_test = sma.add_constant(x_test)

# %%
import statsmodels.api as sm
lm2 = sm.OLS(y_train,x_train).fit()
lm2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.719
# Model:                            OLS   Adj. R-squared:                  0.714
# Method:                 Least Squares   F-statistic:                     162.2
# Date:                Sat, 14 May 2022   Prob (F-statistic):          2.51e-200
# Time:                        19:04:15   Log-Likelihood:                -9153.8
# No. Observations:                 774   AIC:                         1.833e+04
# Df Residuals:                     761   BIC:                         1.839e+04
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
[{x_train.columns[j]:variance_inflation_factor(x_train.values, j) for j in range(x_train.shape[1])}]
# Out:
# [{'const': 241.50199570955667,
#   'LotFrontage': 1.7010131672220679,
#   'LotArea': 1.65115910197332,
#   'MasVnrArea': 1.3759496801500897,
#   '1stFlrSF': 43.89636924245328,
#   '2ndFlrSF': 69.25049102969234,
#   'GrLivArea': 71.5299839394324,
#   'GarageArea': 1.474923808798304,
#   'GarageType_1': 46.5235345246773,
#   'GarageType_2': 3.2842490157225526,
#   'GarageType_3': 10.008548198803277,
#   'GarageType_4': 2.7788030270340554,
#   'GarageType_5': 41.94718558447877}]

# %%
x_train.shape
# Out:
# (774, 13)

# %%
x_train.shape[1]
# Out:
# 13

# %%
def calculate_vif(x):
    thresh = 5.0
    output = pd.DataFrame()
    k = x.shape[1]
    vif = [variance_inflation_factor(x.values, j) for j in range(x.shape[1])]
    for i in range(1,k):
        print("Iteration no: ", i)
        print(vif, '\n')
        a = np.argmax(vif)
        print("Max VIF is for variable no:",a)
        print("Column Name:",x.columns[a], '\n')
      
        if vif[a] <= thresh :
            break
        if i == 1 :          
            x= x.drop(x.columns[a], axis = 1)
            vif = [variance_inflation_factor(x.values, j) for j in range(x.shape[1])]
        elif i > 1 :
            x = x.drop(x.columns[a],axis = 1)
            vif = [variance_inflation_factor(x.values, j) for j in range(x.shape[1])]
    return(x)

# %%
train_out = calculate_vif(x_train)
# Out:
# Iteration no:  1
# [241.50199570955667, 1.7010131672220679, 1.65115910197332, 1.3759496801500897, 43.89636924245328, 69.25049102969234, 71.5299839394324, 1.474923808798304, 46.5235345246773, 3.2842490157225526, 10.008548198803277, 2.7788030270340554, 41.94718558447877]
#
# Max VIF is for variable no: 0
# Column Name: const
#
# Iteration no:  2
# [32.05270983752623, 21.89390982736532, 1.8395542169997376, 597.920380454822, 108.75313402742292, 928.0095985180538, 8.474309947493932, 20.12532539072816, 1.309018478182884, 2.8214476387117204, 1.3112409387625148, 7.948469579271411]
#
# Max VIF is for variable no: 5
# Column Name: GrLivArea
#
# Iteration no:  3
# [31.92817133185903, 21.82196208932481, 1.8373688867629299, 24.393391766282647, 2.262772161091762, 8.406823272564713, 20.115901584757836, 1.3090167111460287, 2.821042708905715, 1.3112362691619308, 7.924308284513862]
#
# Max VIF is for variable no: 0
# Column Name: LotFrontage
#
# Iteration no:  4
# ...

# %%
train_out.head()
# Out:
#       MasVnrArea  2ndFlrSF  GarageType_1  GarageType_2  GarageType_3  GarageType_4  GarageType_5
# 1070       120.0         0             1             0             0             0             0
# 11         286.0      1142             0             0             1             0             0
# 428        108.0         0             1             0             0             0             0
# 1246         0.0       797             1             0             0             0             0
# 1126       130.0         0             1             0             0             0             0

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm = lm.fit(train_out,y_train)

# %%
import statsmodels.api as sm
lm2 = sm.OLS(y_train,train_out).fit()
lm2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared (uncentered):                   0.922
# Model:                            OLS   Adj. R-squared (uncentered):              0.921
# Method:                 Least Squares   F-statistic:                              1289.
# Date:                Sat, 14 May 2022   Prob (F-statistic):                        0.00
# Time:                        19:13:43   Log-Likelihood:                         -9471.4
# No. Observations:                 774   AIC:                                  1.896e+04
# Df Residuals:                     767   BIC:                                  1.899e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...
